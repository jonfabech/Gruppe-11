# %% [markdown]
# # Data fra inside Air-bnb
# http://insideairbnb.com/get-the-data.html

# %%
import pandas as pd

# %%
df_meta = pd.read_csv('listings.csv')

# %%
df_meta
# Out:
#              id                            listing_url       scrape_id  \
# 0      11703409  https://www.airbnb.com/rooms/11703409  20170615002708
# 1      16300314  https://www.airbnb.com/rooms/16300314  20170615002708
# 2      18152717  https://www.airbnb.com/rooms/18152717  20170615002708
# 3      17309528  https://www.airbnb.com/rooms/17309528  20170615002708
# 4      16864730  https://www.airbnb.com/rooms/16864730  20170615002708
# 5      13766533  https://www.airbnb.com/rooms/13766533  20170615002708
# 6      19223755  https://www.airbnb.com/rooms/19223755  20170615002708
# 7       8986448   https://www.airbnb.com/rooms/8986448  20170615002708
# 8       5443160   https://www.airbnb.com/rooms/5443160  20170615002708
# 9       7529914   https://www.airbnb.com/rooms/7529914  20170615002708
# 10      3536990   https://www.airbnb.com/rooms/3536990  20170615002708
# 11     12207328  https://www.airbnb.com/rooms/12207328  20170615002708
# ...

# %%
# helt klar denne, der er mest brugbar!
# problemet er, at vi ikke kender tidsrammen for indsamlingen af data.
df_meta2 = pd.read_csv('listings2.csv')
df_meta2
# Out:
#              id                                               name    host_id  \
# 0      11703409                 Big cozy apartment in a quiet area    1621832
# 1      16300314  Copenhagen apartment for your Copenhagen vacation  106646306
# 2      18152717    Lovely room close to city center in a calm area   62823209
# 3      17309528            Big and cozy apt. with central location   24378880
# 4      16864730                   Modern appartment in City center   86707238
# 5      13766533  Spacious, light apartment in the Copenhagen heart   34954837
# 6      19223755        Bright and cozy apartment centrally located    6143411
# 7       8986448                  Cool apartment close to the city.   46946093
# 8       5443160                     Charming Copenhagen town house   28232441
# 9       7529914                                  Central lejlighed   39460750
# 10      3536990                Perfectly located family friendly     17807602
# ...

# %%
import plotly.plotly as py
import pandas as pd

df = pd.read_csv('listings2.csv')

# %%
df_calendar = pd.read_csv('calendar.csv')
df_calendar.head()
# Out:
#    listing_id        date available    price
# 0    11703409  2018-06-03         t  $700.00
# 1    11703409  2018-06-02         t  $700.00
# 2    11703409  2018-06-01         t  $700.00
# 3    11703409  2018-05-31         t  $700.00
# 4    11703409  2018-05-30         t  $700.00

# %%
df_nabo = pd.read_csv('neighbourhoods.csv')
df_nabo.head()
# Out:
#    neighbourhood_group  neighbourhood
# 0                  NaN    Amager Vest
# 1                  NaN      Amager st
# 2                  NaN     Bispebjerg
# 3                  NaN   Brnshj-Husum
# 4                  NaN  Frederiksberg
